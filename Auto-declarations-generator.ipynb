# %% [markdown]
# ## Generatore autocertificazioni
#
# * Si parte da qui: https://github.com/GiovanniBalestrieri/autodichiarazione_2.0/blob/master/path_planning/basic_example.py
#
# ### Converto in funzione lo script della repo

# %%
def get_itinerary(trip):
    """
    This function takes a tuple of GPS positions tuples (lat, lon) and 
    returns openstreetmaps directions, in 
    terms of gps coordinates array.
    """
    
    import openrouteservice
    from openrouteservice import convert

    # Change your token here
    token = '5b3ce3597851110001cf62488a48a7f1e3ad491184353a3b070c32a2'
    
    # Connect to client
    client = openrouteservice.Client(key=token) # Specify your token

    # decode_polyline needs the geometry only
    geometry = client.directions(trip)['routes'][0]['geometry']
    decoded = convert.decode_polyline(geometry)

    return decoded['coordinates']

#trip = ((12.6067104,42.5917049), (12.6218790,42.5808930))
#directions = get_itinerary(trip)
#print(directions)

# %% [markdown]
# ### Acquisizione coordinate
#
# * I punti di interesse sono immessi manualmente, mentre i domicili sono generati randomicamente
#
# * Il mumero di utenti in questo caso è uguale al numero di punti di partenza: ogni utente fa un trip

# %%
import numpy as np

n_users = 10           # Quanti utenti includere nella simulazione
delta_dist = 0.005      # Raggio della circonferenza che contiene i 
                       # punti di partenza (in gradi decimali)

dpi_list = ["mascherina", "guanti", "guanti e mascherina", "nessuno"]
simptoms_list = ["emicrania", "nausea", "dolori articolari", "respiro affannoso"]

interest_points = [{"name_loc": "CONAD Superstore", "addr": "Via del Rivo, 206, 05100 Terni TR, Italia", "lat":42.580256, "lon":12.621649, "cap": "05100", "type":"acquisti"},
                   {"name_loc": "Farmacia Nadalini", "addr": "Via del Rivo, 98-80, 05100 Terni TR, Italia", "lat":42.579970, "lon":12.625367, "cap": "05100", "type":"acquisti"},
                   {"name_loc": "Unicredit", "addr": "Via del Rivo, 208, 05100 Terni TR, Italia", "lat":42.580893, "lon":12.621879, "cap": "05100", "type":"banca"},
                   {"name_loc": "Ufficio", "addr": "Via del Camoscio, 19, 05100 Terni TR, Italia", "lat":42.582965, "lon":12.619052, "cap": "05100", "type":"ufficio"},
                   {"name_loc": "Ambulatorio", "addr": "Via del Rivo, 93, 05100 Terni TR, Italia", "lat":42.579069, "lon":12.626082, "cap": "05100", "type":"ambulatorio"}]

center_coords = (42.581302, 12.622702)

lats = list(np.random.uniform(center_coords[0]-delta_dist, center_coords[0]+delta_dist, n_users))
lons = list(np.random.uniform(center_coords[1]-delta_dist, center_coords[1]+delta_dist, n_users))
uuids = list(np.random.randint(low = 1000, high = 2000, size=n_users))

starting_points = [list(a) for a in zip(uuids, lats, lons)]

# %% [markdown]
# ### Generazione trip
#
# * Per ogni user, viene scelta una destinazione a caso

# %%
from datetime import datetime, timedelta 
from random import randint

raw_trips = []

for point in starting_points:

    trip = {}
    info = {}
    
    # Scelta destinazione per uuid corrente
    n = np.random.randint(len(interest_points))
    
    trip["uuid"] = int(point[0])
    trip["lat start"] = float(point[1])
    trip["lon start"] = float(point[2])
    trip["lat dest"] = interest_points[n]["lat"]
    trip["lon dest"] = interest_points[n]["lon"]
    trip["name dest"] = interest_points[n]["name_loc"]
    trip["address dest"] = interest_points[n]["addr"]
    trip["cap dest"] = interest_points[n]["cap"]
    trip["type dest"] = interest_points[n]["type"]
    
    # Generazione itinerario
    start_loc = (trip["lon start"], trip["lat start"])
    dest_loc = (trip["lon dest"], trip["lat dest"])
    trip_tuple = (start_loc, dest_loc)
    
    itinerary = get_itinerary(trip_tuple)
    trip["directions"] = list(itinerary)
    
    # Parametri utente
    temperature = np.random.uniform(35.5,37.5)
    simptoms = simptoms_list[np.random.randint(len(simptoms_list))]
    dpi = dpi_list[np.random.randint(len(dpi_list))]
    
    info["temperature"] = temperature
    info["simptoms"] = simptoms
    info["dpi"] = dpi
    
    start_time = datetime.now()
    
    # Add random time delta
    delta_h = 0
    delta_min = 5
    factor = randint(0, 6)
    start_time = start_time + timedelta(hours = delta_h*factor, minutes = delta_min*factor)
    
    info["start time"] = start_time.strftime("%m-%d-%YT%H:%M:%S") 
    
    trip["info"] = info

    raw_trips.append(trip)

# %% [markdown]
# ### Creazione dei geojson a partire dai dizionari dei trip

# %%
import json
from pprint import pprint

trips_dir = "trips/"

json_trips_list = []

for item in raw_trips:
    
    json_trip = json.dumps(item)
    json_trips_list.append(json_trip)
    
    print(json_trip)
    print("\n")
    
    #filename = trips_dir + "trip_" + str(item["uuid"]) + ".geojson"
    
    #with open(filename, 'w') as json_file:
    #    json.dump(item, json_file)
# Out:
# {"uuid": 1146, "lat start": 42.5816319259222, "lon start": 12.619535066328137, "lat dest": 42.580256, "lon dest": 12.621649, "name dest": "CONAD Superstore", "address dest": "Via del Rivo, 206, 05100 Terni TR, Italia", "cap dest": "05100", "type dest": "acquisti", "directions": [[12.61948, 42.58152], [12.61964, 42.58148], [12.62026, 42.58134], [12.62061, 42.58125], [12.62045, 42.58092], [12.62025, 42.58051], [12.62025, 42.58041], [12.6203, 42.58031], [12.62041, 42.58023], [12.62051, 42.58017], [12.6207, 42.58038], [12.62079, 42.58034], [12.62134, 42.58004], [12.62145, 42.58008], [12.6216, 42.58006]], "info": {"temperature": 35.683674648741274, "simptoms": "emicrania", "dpi": "mascherina", "start time": "04-03-2020T13:24:23"}}
#
#
# {"uuid": 1443, "lat start": 42.58038175998982, "lon start": 12.620365078786095, "lat dest": 42.580256, "lon dest": 12.621649, "name dest": "CONAD Superstore", "address dest": "Via del Rivo, 206, 05100 Terni TR, Italia", "cap dest": "05100", "type dest": "acquisti", "directions": [[12.62028, 42.58036], [12.6203, 42.58031], [12.62041, 42.58023], [12.62051, 42.58017], [12.6207, 42.58038], [12.62079, 42.58034], [12.62134, 42.58004], [12.62145, 42.58008], [12.6216, 42.58006]], "info": {"temperature": 37.32715461349692, "simptoms": "emicrania", "dpi": "nessuno", "start time": "04-03-2020T13:39:23"}}
#
#
# {"uuid": 1615, "lat start": 42.57748737797391, "lon start": 12.618653323284937, "lat dest": 42.579069, "lon dest": 12.626082, "name dest": "Ambulatorio", "address dest": "Via del Rivo, 93, 05100 Terni TR, Italia", "cap dest": "05100", "type dest":
 05100 Terni TR, Italia", "cap dest": "05100", "type dest": "banca", "directions": [[12.62653, 42.57667], [12.62652, 42.5768], [12.6265, 42.57703], [12.6264, 42.57747], [12.62636, 42.57768], [12.62633, 42.57781], [12.62631, 42.57786], [12.62626, 42.57807], [12.62623, 42.5782], [12.62623, 42.57822], [12.62617, 42.57847], [12.62604, 42.5789], [12.62595, 42.57933], [12.62593, 42.57961], [12.62583, 42.5797], [12.6255, 42.57983], [12.62515, 42.57996], [12.6245, 42.58019], [12.62426, 42.58027], [12.62297, 42.58068], [12.6221, 42.58088], [12.6219, 42.58093]], "info": {"temperature": 36.69125849439443, "simptoms": "nausea", "dpi": "mascherina", "start time": "04-03-2020T13:19:24"}}
#
#
# {"uuid": 1650, "lat start": 42.58066900494308, "lon start": 12.618692215895768, "lat dest": 42.580256, "lon dest": 12.621649, "name dest": "CONAD Superstore", "address dest": "Via del Rivo, 206, 05100 Terni TR, Italia", "cap dest": "05100", "type dest": "acquisti", "directions": [[12.61878, 42.58077], [12.61934, 42.58053], [12.61954, 42.58045], [12.61975, 42.58036], [12.61992, 42.58029], [12.62011, 42.58019], [12.62036, 42.58007], [12.62152, 42.57943], [12.62168, 42.57934], [12.62182, 42.57926], [12.62229, 42.57898], [12.62255, 42.57881], [12.62231, 42.57904], [12.62206, 42.57923], [12.62177, 42.5795], [12.62195, 42.57997], [12.62178, 42.58002], [12.62161, 42.58006], [12.6216, 42.58006]], "info": {"temperature": 35.914756160809624, "simptoms": "dolori articolari", "dpi": "guanti", "start time": "04-03-2020T13:14:24"}}

# %% [markdown]
# ### Upload to the Tangle

# %%
from iota import Iota, TryteString, Tag, ProposedTransaction
from iota.crypto.types import Seed
    
# Generate Seed and retrieve address
my_seed = Seed.random(length=81)
print('Your seed is: ' + str(my_seed))

# Declare an API object
api = Iota(
    adapter='https://nodes.devnet.iota.org:443',
    seed=my_seed,
    testnet=True,
)

print('Generating the first unused address...')
# Generate an address from your seed to post the transfer to
my_address = api.get_new_addresses(index=42)['addresses'][0]
print("Remember this address")
print(my_address)

print('Constructing transaction locally...')
    
def push_to_tangle(json_payload, my_address):
    """
    Pushing declaration to the distributed 
    digital ledger, the Tangle.
    iota >>> pip3 install pyota
    """

    # Convert to trytes
    trytes_data_user = TryteString.from_unicode(json_payload)

    # Tag is optional here
    my_tag = Tag(b'TESTINFORMATION')

    # Prepare a transaction object for user1
    tx_user = ProposedTransaction(
        address=my_address,
        value=0,
        tag=my_tag,
        message=trytes_data_user,
    )

    print('Sending transfer...')

    # Send the transaction to the network
    response = api.send_transfer([tx_user])

    print('Check your transaction on the Tangle for user')
    print('https://utils.iota.org/transaction/%s/devnet' % response['bundle'][0].hash)
    print('Tail transaction hash of the bundle is: %s' % response['bundle'].tail_transaction.hash)
    print('Done')
    
    return response['bundle'].tail_transaction.hash
# Out:
# Your seed is: ZINQQUPEYHWRBOCXHPIBLSHJTFIALHFJJMHOEYGAF9BKNZOJMPMWKNWEZIBQPRSCLHSPHNJIHRTUUPELF
# Generating the first unused address...
# Remember this address
# FNVOAXUEWEGMDRYUFIPCTQOOXIIKBINADOEEHFHLQ9WNZSOCMEOUTIT999HBBFPFBAQGPQCL9UWLRWOIW
# Constructing transaction locally...

# %%
list_hash = {}

idx = 0
for json_trip in json_trips_list:

    list_hash[str(idx)] = str(push_to_tangle(json_trip, my_address)) 
    #list_hash.append(str(push_to_tangle(json_trip, my_address)))
    idx = idx + 1

print(list_hash)
    
with open("hash_list.json", 'w') as json_file:
    #json_temp = json.dumps(list_hash)
    json.dump(list_hash, json_file)
# Out:
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/ZKSTULUBZ9RGOXKHYXZMNIKEHAD9YCXIQAISEJMTAIFJGSRSTKFGSCYKYNSQOIZCJ9TNYLOAUA9OPI999/devnet
# Tail transaction hash of the bundle is: ZKSTULUBZ9RGOXKHYXZMNIKEHAD9YCXIQAISEJMTAIFJGSRSTKFGSCYKYNSQOIZCJ9TNYLOAUA9OPI999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/VNVLAIAAYCZOS9ZSWZFDKMQIKHECSWJEGKTNUPMOUQ9ETCHISCUKHUFXLHB9RQMKBXS9ZEUFVMKQPX999/devnet
# Tail transaction hash of the bundle is: VNVLAIAAYCZOS9ZSWZFDKMQIKHECSWJEGKTNUPMOUQ9ETCHISCUKHUFXLHB9RQMKBXS9ZEUFVMKQPX999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/RSWHAXFXQHNHOYRMLZJQDRWAOOLUJEDECBZIDQYQDLXJQDHDJAXQNNWJCPFPMVXDCCDNUBOSW9GTCI999/devnet
# Tail transaction hash of the bundle is: RSWHAXFXQHNHOYRMLZJQDRWAOOLUJEDECBZIDQYQDLXJQDHDJAXQNNWJCPFPMVXDCCDNUBOSW9GTCI999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/NQVAV9EIOBKIGKOVVUMGYDGUZZQIY9WBOHXJLAV9ZXDDQTSEQUGRIUVJFEXEZCJLMJNLBJBMIRZNZ9999/devnet
# Tail transaction hash of the bundle is: NQVAV9EIOBKIGKOVVUMGYDGUZZQIY9WBOHXJLAV9ZXDDQTSEQUGRIUVJFEXEZCJLMJNLBJBMIRZNZ9999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/ZWGRNHVOSIWSJZVSFRZZBPBWGKRIJHRFLS9AAKRUWJHINOLOKKZKBOUVTWWRNQGASZTZUQJUUSIMRF999/devnet
# Tail transaction hash of the bundle is: ZWGRNHVOSIWSJZVSFRZZBPBWGKRIJHRFLS9AAKRUWJHINOLOKKZKBOUVTWWRNQGASZTZUQJUUSIMRF999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/PDRQBCNSMSW9DBZWIXOYXBAIHQGHYOVCY9RCYAKTTYBSUIQDMTPQWTZAGBZFGDACMYKO9VBPFIRMOZ999/devnet
# Tail transaction hash of the bundle is: PDRQBCNSMSW9DBZWIXOYXBAIHQGHYOVCY9RCYAKTTYBSUIQDMTPQWTZAGBZFGDACMYKO9VBPFIRMOZ999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction/ZVDXTZPSNPPKWSICJULZPSAJBWPAOFTX9FFCZH9CCOXHWSBJAKQWVTJEAYDGSKRFWQRWFCLYDGQXWO999/devnet
# Tail transaction hash of the bundle is: ZVDXTZPSNPPKWSICJULZPSAJBWPAOFTX9FFCZH9CCOXHWSBJAKQWVTJEAYDGSKRFWQRWFCLYDGQXWO999
# Done
# Sending transfer...
# Check your transaction on the Tangle for user
# https://utils.iota.org/transaction